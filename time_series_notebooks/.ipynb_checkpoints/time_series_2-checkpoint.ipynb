# %% [markdown]
# # Using market data
#
# resouce: https://github.com/urgedata/pythondata/blob/master/fbprophet/fbprophet_market_forecasts.ipynb

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# %matplotlib inline

plt.rcParams['figure.figsize']=(20,10)
plt.style.use('ggplot')

# %%
market_df = pd.read_csv('../data/sp500.csv', index_col='DATE', parse_dates=True)
market_df.head()
# Out:
#               SP500
# DATE
# 2017-08-30  2457.59
# 2017-08-29  2446.30
# 2017-08-28  2444.24
# 2017-08-25  2443.05
# 2017-08-24  2438.97

# %%
market_df.plot()

# %%
df = market_df.reset_index().rename(columns={'DATE':'ds', 'SP500':'y'})
df['y'] = np.log(df['y'])
df.head()
# Out:
#           ds         y
# 0 2017-08-30  7.806936
# 1 2017-08-29  7.802332
# 2 2017-08-28  7.801490
# 3 2017-08-25  7.801003
# 4 2017-08-24  7.799331

# %% [markdown]
# ## Running Prophet

# %%
model = Prophet()
model.fit(df);
future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
figure = model.plot(forecast)
